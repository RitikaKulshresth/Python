# %%
# Write a function that converts a dictionary back to its sparse vector representation.
# In - convertDictionary({0: 1, 3: 2, 7: 3, 12: 4})
# Out - [1, 0, 0, 2, 0, 0, 0, 3, 0, 0, 0, 0, 4]
# In - convertDictionary({0: 1, 2: 1, 4: 2, 6: 1, 9: 1})
# Out - [1, 0, 1, 0, 2, 0, 1, 0, 0, 1]
# In - convertDictionary({})
# Out - []
def convertDictionary(dictionary):
    var_k=dictionary.keys()
    var_v=dictionary.values()
    l1=[]
    for i in range(0,len(var_k)):
        l1.append(0)
    for j in range(0,len(var_k)):
        l1[j]=var_v[var_k(j)]
    print(l1)

# %%
# Write the code to get the total count of 't' in above string. Use: 
# find() method and 
# index() method [This is optional]

# %%
my_str = "Hello everyone, this is Python session. We are solving doubts on dictionary, strings and lists."

# %%
my_str.find('t')
# Out:
# 16

# %%
count = 0
i = 0
while i < len(my_str):
    temp_str = my_str[i:]
    index_t = temp_str.find('t')
    if index_t != -1:
        count += 1
        i = index_t + 1
    else:
        break
        
print(count)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 count = 0
#       2 i = 0
# ----> 3 while i < len(my_str):
#       4     temp_str = my_str[i:]
#       5     index_t = temp_str.find('t')
#
# KeyboardInterrupt:

# %%
count = 0
i = 0
while i < len(my_str):
    temp_str = my_str[i:]
    print(temp_str)
    index_t = temp_str.find('t')
    print(index_t)
    if index_t != -1:
        count += 1
        i = index_t + 1
    else:
        break
        
print(count)
# Out:
# Hello everyone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 16
# his is Python session. We are solving doubts on dictionary, strings and lists.
# 9
# yone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 6
# veryone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 9
# yone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 6
# veryone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 9
# yone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 6
# veryone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 9
# yone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 6
# veryone, this is Python session. We are solving doubts on dictionary, strings and lists.
# 9
# ...

# %%
help(my_str.find)
# Out:
# Help on built-in function find:
#
# find(...) method of builtins.str instance
#     S.find(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Return -1 on failure.

# %%
count=0
index=my_str.find('t')

while index!= -1:
    count+=1
    index=my_str.find('t',index+1)
    
print(count)
# Out:
# 6

# %%
count = 0
i = 0
while i < len(my_str):
    index_t = temp_str.find('t', i)
    print(index_t)
    if index_t != -1:
        count += 1
        i = index_t + 1
    else:
        break
        
print(count)
# Out:
# 6
# 16
# 49
# 58
# 68
# 82
# -1
# 6

# %%
count = 0
i = 0
while i < len(my_str):
    index_t = temp_str.find('t', i)
    # print(index_t)
    if index_t != -1:
        count += 1
        i = index_t + 1
    else:
        break
        
print(count)
# Out:
# 6

# %%
# how to find The first character in my_str  Using len() function

# %%
my_str
# Out:
# 'Hello everyone, this is Python session. We are solving doubts on dictionary, strings and lists.'

# %%
my_str[-len(my_str)]
# Out:
# 'H'

# %%
# Create a dictionary out of below inputs 

# lst1 = ['emp1', 'emp2', 'emp3'] 

# emp_key = ['e_name', 'e_id', 'e_sal'] 

# emp1_val = ['John', 'SG101', '$10,000'] 

# emp2_val = ['Smith', 'SG102', '$9,000'] 

# emp3_val = ['Peter', 'SG103', '$9,500']. 

# Expected Output:- {'emp1':{'e_name':'John', 'e_id':'SG101', 'e_sal':$10,000}, 
#                    'emp2':{'e_name':'Smith', 'e_id':'SG102', 'e_sal':$9,000}, 
#                    'emp3':{'e_name':'Peter', 'e_id':'SG103', 'e_sal':$9,500}}

# %%
lst1 = ['emp1', 'emp2', 'emp3']

# %%
emp_key = ['e_name', 'e_id', 'e_sal']

# %%
emp1_val = ['John', 'SG101', '$10,000'] 
emp2_val = ['Smith', 'SG102', '$9,000']
emp3_val = ['Peter', 'SG103', '$9,500']

# %%
emp_list = [emp1_val, emp2_val, emp3_val]

# %%
emp_list
# Out:
# [['John', 'SG101', '$10,000'],
#  ['Smith', 'SG102', '$9,000'],
#  ['Peter', 'SG103', '$9,500']]

# %%
for emp in emp_list:
    print(emp)
# Out:
# ['John', 'SG101', '$10,000']
# ['Smith', 'SG102', '$9,000']
# ['Peter', 'SG103', '$9,500']

# %%
for emp in emp_list:
    print(emp[0])
# Out:
# John
# Smith
# Peter

# %%
emp_key
# Out:
# ['e_name', 'e_id', 'e_sal']

# %%
for emp in emp_list:
    inner_dict = {}
    inner_dict.update({emp_key[0] : emp[0]})
    inner_dict.update({emp_key[1] : emp[1]})
    inner_dict.update({emp_key[2] : emp[2]})
    print(inner_dict)
# Out:
# {'e_name': 'John', 'e_id': 'SG101', 'e_sal': '$10,000'}
# {'e_name': 'Smith', 'e_id': 'SG102', 'e_sal': '$9,000'}
# {'e_name': 'Peter', 'e_id': 'SG103', 'e_sal': '$9,500'}

# %%
out_list = []
for emp in emp_list:
    inner_dict = {}
    inner_dict.update({emp_key[0] : emp[0]})
    inner_dict.update({emp_key[1] : emp[1]})
    inner_dict.update({emp_key[2] : emp[2]})
    out_list.append(inner_dict)

# %%
out_list
# Out:
# [{'e_name': 'John', 'e_id': 'SG101', 'e_sal': '$10,000'},
#  {'e_name': 'Smith', 'e_id': 'SG102', 'e_sal': '$9,000'},
#  {'e_name': 'Peter', 'e_id': 'SG103', 'e_sal': '$9,500'}]

# %%
out_dict = {}

# %%
for i in range(len(out_list)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
lst1
# Out:
# ['emp1', 'emp2', 'emp3']

# %%
for i in range(len(out_list)):
    out_dict.update({lst1[i]:out_list[i]})

# %%
out_dict
# Out:
# {'emp1': {'e_name': 'John', 'e_id': 'SG101', 'e_sal': '$10,000'},
#  'emp2': {'e_name': 'Smith', 'e_id': 'SG102', 'e_sal': '$9,000'},
#  'emp3': {'e_name': 'Peter', 'e_id': 'SG103', 'e_sal': '$9,500'}}

# %%
# How to take list as an input from the user?

# %%
lst = input("Enter a list: ")
# Out:
# Enter a list: [1, 2, 3]

# %%
lst
# Out:
# '[1, 2, 3]'

# %%
list(lst)
# Out:
# ['[', '1', ',', ' ', '2', ',', ' ', '3', ']']

# %%
lst.split()
# Out:
# ['[1,', '2,', '3]']

# %%
lst.split(',')
# Out:
# ['[1', ' 2', ' 3]']

# %%
lst.split(' ')
# Out:
# ['[1,', '2,', '3]']

# %%
# eval()

# %%
eval(lst)
# Out:
# [1, 2, 3]

# %%
lst1 = eval(lst)

# %%
lst1
# Out:
# [1, 2, 3]

# %%
type(lst1)
# Out:
# list

# %%
lst1[0]
# Out:
# 1

# %%
lst = eval(input("Enter a list: "))
# Out:
# Enter a list: [1,2,3,4]

# %%
lst
# Out:
# [1, 2, 3, 4]

# %%
type(lst)
# Out:
# list

# %%
#List
#Write a Python program which takes a list from the user and prints it after reshuffling the elements of the list.
#Input:- [10,21,22,98,87,45,33,1,2,100]
#Output:- [1,87,21,10,33,2,100,45,98,22] (It may be any randon list but with same elements)
inp_lst = [10,21,22,98,87,45,33,1,2,100]

# %%
#Write a Python program which takes two list as input and returns True if they have at least 3 common elements.
#inp_lst1 = [10,20,'Python', 10.20, 10+20j, [10,20,30], (10,20,30)]
#inp_lst2 = [(10,20,30),1,20+3j,100.2, 10+20j, [10,20,30],'Python']
#Output:- True

count =  False
inp_lst1 = [10,20,'Python', 10.20, 10+20j, [10,20,30], (10,20,30)]
inp_lst2 = [(10,20,30),1,20+3j,100.2, 10+20j, [10,20,30],'Python']
out_lst = inp_lst1 + inp_lst2
orglen = len(out_lst)
new_lst = list(set(out_lst))
if orglen - len(new_lst) >= 3: 
        count = True
print(count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 11
#       9 out_lst = inp_lst1 + inp_lst2
#      10 orglen = len(out_lst)
# ---> 11 new_lst = list(set(out_lst))
#      12 if orglen - len(new_lst) >= 3:
#      13         count = True
#
# TypeError: unhashable type: 'list'

# %%
out_lst
# Out:
# [10,
#  20,
#  'Python',
#  10.2,
#  (10+20j),
#  [10, 20, 30],
#  (10, 20, 30),
#  (10, 20, 30),
#  1,
#  (20+3j),
#  100.2,
#  (10+20j),
#  [10, 20, 30],
#  'Python']
