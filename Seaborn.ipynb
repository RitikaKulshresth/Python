# %% [markdown]
# https://seaborn.pydata.org/

# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pokemon_df = pd.read_csv('pokemon.csv')

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
pokemon_df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
pokemon_df.describe(include=[object, bool])
# Out:
#              Name Type 1  Type 2 Legendary
# count         800    800     414       800
# unique        800     18      18         2
# top     Bulbasaur  Water  Flying     False
# freq            1    112      97       735

# %%
pokemon_df['Legendary'].unique()
# Out:
# array([False,  True])

# %%
pokemon_df['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
pokemon_df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
len(pokemon_df['Type 1'].unique())
# Out:
# 18

# %%
pokemon_df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
len(pokemon_df['Type 2'].unique())
# Out:
# 19

# %%
pokemon_df['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
pokemon_df['Type 2'].mode()
# Out:
# 0    Flying
# Name: Type 2, dtype: object

# %%
pokemon_df['Type 2'].mode().iloc[0]
# Out:
# 'Flying'

# %%
# Find out unique values for all the columns

# %%
pokemon_df.nunique()
# Out:
# #             721
# Name          800
# Type 1         18
# Type 2         18
# Total         200
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
pokemon_df['Generation'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
pokemon_df['Generation'].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
pokemon_df['Generation'].astype('category')
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 795    6
# 796    6
# 797    6
# 798    6
# 799    6
# Name: Generation, Length: 800, dtype: category
# Categories (6, int64): [1, 2, 3, 4, 5, 6]

# %%
pokemon_df['Generation'] = pokemon_df['Generation'].astype('category')

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    category
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), int64(8), object(3)
# memory usage: 70.7+ KB

# %%
pokemon_df.describe(include=[object, bool, category])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 pokemon_df.describe(include=[object, bool, category])
#
# NameError: name 'category' is not defined

# %%
pokemon_df.describe(include=[object, bool, 'category'])
# Out:
#              Name Type 1  Type 2  Generation Legendary
# count         800    800     414         800       800
# unique        800     18      18           6         2
# top     Bulbasaur  Water  Flying           1     False
# freq            1    112      97         166       735

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed
# count  800.000000  800.000000
# mean    71.902500   68.277500
# std     27.828916   29.060474
# min     20.000000    5.000000
# 25%     50.000000   45.000000
# 50%     70.000000   65.000000
# 75%     90.000000   90.000000
# ...

# %%
# Titanic dataset

# %%
titanic_df = pd.read_csv("Titanic.csv")

# %%
titanic_df
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived
# 0            1
# 1            0
# 2            0
# ...

# %%
titanic_df.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
titanic_df.head(7)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
# 5                             Anderson, Mr Harry    1st  47.00    male
# 6               Andrews, Miss Kornelia Theodosia    1st  63.00  female
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1
# 5         1
# 6         1

# %%
titanic_df.tail(7)
# Out:
#                         Name PClass   Age     Sex  Survived
# 1306     Zabour, Miss Hileni    3rd   NaN  female         0
# 1307     Zabour, Miss Tamini    3rd   NaN  female         0
# 1308      Zakarian, Mr Artun    3rd  27.0    male         0
# 1309  Zakarian, Mr Maprieder    3rd  26.0    male         0
# 1310        Zenni, Mr Philip    3rd  22.0    male         0
# 1311        Lievens, Mr Rene    3rd  24.0    male         0
# 1312          Zimmerman, Leo    3rd  29.0    male         0

# %%
titanic_df.tail()
# Out:
#                         Name PClass   Age   Sex  Survived
# 1308      Zakarian, Mr Artun    3rd  27.0  male         0
# 1309  Zakarian, Mr Maprieder    3rd  26.0  male         0
# 1310        Zenni, Mr Philip    3rd  22.0  male         0
# 1311        Lievens, Mr Rene    3rd  24.0  male         0
# 1312          Zimmerman, Leo    3rd  29.0  male         0

# %%
titanic_df.sample()
# Out:
#                          Name PClass   Age   Sex  Survived
# 706  Carlsson, Mr Carl Robert    3rd  24.0  male         0

# %%
titanic_df.sample()
# Out:
#                             Name PClass  Age     Sex  Survived
# 893  Johnson, Miss Eleanor Ileen    3rd  1.0  female         1

# %%
titanic_df.sample()
# Out:
#                                           Name PClass  Age   Sex  Survived
# 1208  Sholt, Mr Peter Andreas Lauritz Andersen    3rd  NaN  male         0

# %%
titanic_df.sample(5)
# Out:
#                                                    Name PClass   Age     Sex  \
# 1183                           Salonen, Mr Johan Werner    3rd   NaN    male
# 1011                        Meanwell, Miss Marion Ogden    3rd   NaN  female
# 135   Hays, Mrs Charles Melville (Clara Jennings Gregg)    1st  52.0  female
# 949                           Larsson, Mr August Viktor    3rd  29.0    male
# 1126                          Peter (Joseph), Miss Mary    3rd   NaN  female
#
#       Survived
# 1183         0
# 1011         0
# 135          1
# 949          0
# 1126         0

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1312 non-null   object
#  2   Age       756 non-null    float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 51.4+ KB

# %%
titanic_df['Survived'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
titanic_df['Survived'].value_counts()
# Out:
# 0    863
# 1    450
# Name: Survived, dtype: int64

# %%
titanic_df.describe()
# Out:
#               Age     Survived
# count  756.000000  1313.000000
# mean    30.397989     0.342727
# std     14.259049     0.474802
# min      0.170000     0.000000
# 25%     21.000000     0.000000
# 50%     28.000000     0.000000
# 75%     39.000000     1.000000
# max     71.000000     1.000000

# %%
titanic_df.describe(include=object)
# Out:
#                        Name PClass   Sex
# count                  1313   1312  1313
# unique                 1310      3     2
# top     Connolly, Miss Kate    3rd  male
# freq                      2    711   851

# %%
titanic_df['PClass'].value_counts()
# Out:
# 3rd    711
# 1st    322
# 2nd    279
# Name: PClass, dtype: int64

# %%
titanic_df['Sex'].value_counts()
# Out:
# male      851
# female    462
# Name: Sex, dtype: int64

# %%
help(titanic_df['PClass'].value_counts)
# Out:
# Help on method value_counts in module pandas.core.base:
#
# value_counts(normalize: 'bool' = False, sort: 'bool' = True, ascending: 'bool' = False, bins=None, dropna: 'bool' = True) -> 'Series' method of pandas.core.series.Series instance
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : bool, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#     bins : int, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : bool, default True
# ...

# %%
titanic_df.isnull().sum()
# Out:
# Name          0
# PClass        1
# Age         557
# Sex           0
# Survived      0
# dtype: int64

# %%
titanic_df['PClass'].value_counts(dropna=False)
# Out:
# 3rd    711
# 1st    322
# 2nd    279
# NaN      1
# Name: PClass, dtype: int64

# %%
titanic_df['PClass'].value_counts(dropna=False, normalize=True)
# Out:
# 3rd    0.541508
# 1st    0.245240
# 2nd    0.212490
# NaN    0.000762
# Name: PClass, dtype: float64

# %%
titanic_df['PClass'].value_counts(dropna=False, normalize=True) * 100
# Out:
# 3rd    54.150800
# 1st    24.523991
# 2nd    21.249048
# NaN     0.076161
# Name: PClass, dtype: float64

# %%
711/1313
# Out:
# 0.5415079969535415

# %%
titanic_df['PClass'].value_counts(dropna=False) / len(titanic_df)
# Out:
# 3rd    0.541508
# 1st    0.245240
# 2nd    0.212490
# NaN    0.000762
# Name: PClass, dtype: float64

# %%
titanic_df.describe(include='all')
# Out:
#                        Name PClass         Age   Sex     Survived
# count                  1313   1312  756.000000  1313  1313.000000
# unique                 1310      3         NaN     2          NaN
# top     Connolly, Miss Kate    3rd         NaN  male          NaN
# freq                      2    711         NaN   851          NaN
# mean                    NaN    NaN   30.397989   NaN     0.342727
# std                     NaN    NaN   14.259049   NaN     0.474802
# min                     NaN    NaN    0.170000   NaN     0.000000
# 25%                     NaN    NaN   21.000000   NaN     0.000000
# 50%                     NaN    NaN   28.000000   NaN     0.000000
# 75%                     NaN    NaN   39.000000   NaN     1.000000
# max                     NaN    NaN   71.000000   NaN     1.000000

# %%
titanic_df.columns
# Out:
# Index(['Name', 'PClass', 'Age', 'Sex', 'Survived'], dtype='object')

# %%
titanic_df.query("Name == 'Connolly, Miss Kate'")
# Out:
#                     Name PClass   Age     Sex  Survived
# 728  Connolly, Miss Kate    3rd  30.0  female         0
# 729  Connolly, Miss Kate    3rd  22.0  female         1

# %%
# How to find duplicate rows

# %%
titanic_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1308    False
# 1309    False
# 1310    False
# 1311    False
# 1312    False
# Length: 1313, dtype: bool

# %%
titanic_df[titanic_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, PClass, Age, Sex, Survived]
# Index: []

# %%
# We delete the duplicate rows

# %%
# Distribution plot

# %%
# it takes a numerical column to plot the distribution

# %%
titanic_df.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
sns.displot(x='Age', data=titanic_df)

# %%
titanic_df['Age'].min()
# Out:
# 0.17

# %%
titanic_df['Age'].max()
# Out:
# 71.0

# %%
sns.displot(x='Age', data=titanic_df, bins=7)

# %%
sns.displot(x='Age', data=titanic_df, bins=7, color='green')

# %%
help(sns.displot)
# Out:
# Help on function displot in module seaborn.distributions:
#
# displot(data=None, *, x=None, y=None, hue=None, row=None, col=None, weights=None, kind='hist', rug=False, rug_kws=None, log_scale=None, legend=True, palette=None, hue_order=None, hue_norm=None, color=None, col_wrap=None, row_order=None, col_order=None, height=5, aspect=1, facet_kws=None, **kwargs)
#     Figure-level interface for drawing distribution plots onto a FacetGrid.
#
#     This function provides access to several approaches for visualizing the
#     univariate or bivariate distribution of data, including subsets of data
#     defined by semantic mapping and faceting across multiple subplots. The
#     ``kind`` parameter selects the approach to use:
#
#     - :func:`histplot` (with ``kind="hist"``; the default)
#     - :func:`kdeplot` (with ``kind="kde"``)
#     - :func:`ecdfplot` (with ``kind="ecdf"``; univariate-only)
#
#     Additionally, a :func:`rugplot` can be added to any kind of plot to show
# ...

# %%
sns.kdeplot(x='Age', data=titanic_df)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(x='Age', data=titanic_df, kde=True)

# %%
sns.displot(x='Age', data=titanic_df, kde=True, bins=7)

# %%
# Categorical plot
# altleast 1 categorical column for plotting

# %%
titanic_df
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived
# 0            1
# 1            0
# 2            0
# ...

# %%
# countplot()

# %%
sns.countplot(x='PClass', data=titanic_df)
plt.show()

# %%
sns.countplot(x='Sex', data=titanic_df)
plt.show()

# %%
sns.countplot(x='Survived', data=titanic_df)
plt.show()

# %%
# Find out how many passengers survived in each PClass category

# %%
# 1st class

# %%
titanic_df.query("PClass == '1st' and Survived == 1")
# Out:
#                                              Name PClass    Age     Sex  \
# 0                    Allen, Miss Elisabeth Walton    1st  29.00  female
# 4                   Allison, Master Hudson Trevor    1st   0.92    male
# 5                              Anderson, Mr Harry    1st  47.00    male
# 6                Andrews, Miss Kornelia Theodosia    1st  63.00  female
# 8    Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.00  female
# ..                                            ...    ...    ...     ...
# 311                            LeRoy, Miss Berthe    1st    NaN  female
# 313                                   Maloney, Ms    1st    NaN  female
# 315                                 Pericault, Ms    1st    NaN  female
# 318                           Segesser, Mlle Emma    1st    NaN  female
# 321                              Wilson, Ms Helen    1st    NaN  female
#
#      Survived
# 0           1
# 4           1
# 5           1
# 6           1
# 8           1
# ...

# %%
len(titanic_df.query("PClass == '1st' and Survived == 1"))
# Out:
# 193

# %%
titanic_df.query("PClass == '1st' and Survived == 1").count()
# Out:
# Name        193
# PClass      193
# Age         139
# Sex         193
# Survived    193
# dtype: int64

# %%
titanic_df.query("PClass == '2nd' and Survived == 1")
# Out:
#                                  Name PClass   Age     Sex  Survived
# 323          Abelson, Mrs Samuel (An)    2nd  28.0  female         1
# 327   Angle, Mrs William A (Florence)    2nd  32.0  female         1
# 331             Balls, Mrs Ada E Hall    2nd  36.0  female         1
# 334                  Beane, Mr Edward    2nd  32.0    male         1
# 335  Beane, Mrs Edward (Ethel Clarke)    2nd  19.0  female         1
# ..                                ...    ...   ...     ...       ...
# 593              Wilhelms, Mr Charles    2nd  32.0    male         1
# 594     Wilkinson, Mrs Elizabeth Anne    2nd   NaN  female         1
# 595       Williams, Mr Charles Eugene    2nd   NaN    male         1
# 596               Wright, Miss Marion    2nd  26.0  female         1
# 599               Brown, Miss Mildred    2nd  24.0  female         1
#
# [119 rows x 5 columns]

# %%
titanic_df.query("PClass == '3rd' and Survived == 1")
# Out:
#                                    Name PClass   Age     Sex  Survived
# 605          Abbott, Mrs Stanton (Rosa)    3rd  35.0  female         1
# 606             Abelseth, Miss An Karen    3rd  16.0  female         1
# 607                  Abelseth, Mr Olaus    3rd  25.0    male         1
# 608   Abraham, Mrs Joseph (Sophie Easu)    3rd  18.0  female         1
# 609              Abrahamsson, Mr August    3rd  20.0    male         1
# ...                                 ...    ...   ...     ...       ...
# 1279                Vartunian, Mr David    3rd  22.0    male         1
# 1289      Wennerstrom, Mr August Edvard    3rd   NaN    male         1
# 1293                  Wilkes, Mrs Ellen    3rd  45.0  female         1
# 1302                  Yalsevac, Mr Ivan    3rd   NaN    male         1
# 1304                Yasbeck, Mrs Antoni    3rd  15.0  female         1
#
# [138 rows x 5 columns]

# %%
# Find out how many passengers died in each PClass category

# %%
titanic_df.query("PClass == '3rd' and Survived == 0")
# Out:
#                                Name PClass   Age   Sex  Survived
# 602              Abbing, Mr Anthony    3rd  42.0  male         0
# 603    Abbott, Master Eugene Joseph    3rd  13.0  male         0
# 604      Abbott, Mr Rossmore Edward    3rd  16.0  male         0
# 610   Adahl, Mr Mauritz Nils Martin    3rd  30.0  male         0
# 611                  Adams, Mr John    3rd  26.0  male         0
# ...                             ...    ...   ...   ...       ...
# 1308             Zakarian, Mr Artun    3rd  27.0  male         0
# 1309         Zakarian, Mr Maprieder    3rd  26.0  male         0
# 1310               Zenni, Mr Philip    3rd  22.0  male         0
# 1311               Lievens, Mr Rene    3rd  24.0  male         0
# 1312                 Zimmerman, Leo    3rd  29.0  male         0
#
# [573 rows x 5 columns]

# %%
titanic_df.query("PClass == '2nd' and Survived == 0")
# Out:
#                               Name PClass   Age     Sex  Survived
# 322             Abelson, Mr Samuel    2nd  30.0    male         0
# 324        Andrew, Mr Edgar Samuel    2nd  18.0    male         0
# 325               Andrew, Mr Frank    2nd   NaN    male         0
# 326            Angle, Mr William A    2nd  34.0    male         0
# 328                 Ashby, Mr John    2nd  57.0    male         0
# ..                             ...    ...   ...     ...       ...
# 592          Wheeler, Mr Frederick    2nd   NaN    male         0
# 597          Yrois, Miss Henriette    2nd   NaN  female         0
# 598  Aldworth, Mr Charles Augustus    2nd  30.0    male         0
# 600                Pernot, Mr Rene    2nd   NaN    male         0
# 601               Swane, Mr George    2nd  18.0    male         0
#
# [160 rows x 5 columns]

# %%
titanic_df.query("PClass == '1st' and Survived == 0")
# Out:
#                                               Name PClass   Age     Sex  \
# 1                      Allison, Miss Helen Loraine    1st   2.0  female
# 2              Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3    Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
# 7                           Andrews, Mr Thomas, jr    1st  39.0    male
# 9                           Artagaveytia, Mr Ramon    1st  71.0    male
# ..                                             ...    ...   ...     ...
# 314                                    Oliva, Mlle    1st   NaN  female
# 316                             Ringhini, Mr Sante    1st  33.0    male
# 317                             Robbins, Mr Victor    1st   NaN    male
# 319                                   Seredeca, Ms    1st   NaN  female
# 320                                    Ward, Ms An    1st   NaN  female
#
#      Survived
# 1           0
# 2           0
# 3           0
# 7           0
# 9           0
# ...

# %%
sns.countplot(x='PClass', data=titanic_df, hue='Survived')
plt.show()

# %%
help(sns.countplot)
# Out:
# Help on function countplot in module seaborn.categorical:
#
# countplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, ax=None, **kwargs)
#     Show the counts of observations in each categorical bin using bars.
#
#     A count plot can be thought of as a histogram across a categorical, instead
#     of quantitative, variable. The basic API and options are identical to those
#     for :func:`barplot`, so you can compare counts across nested variables.
#
#     Note that the newer :func:`histplot` function offers more functionality, although
#     its default behavior is somewhat different.
#
#     .. note::
#         This function always treats one of the variables as categorical and
#         draws data at ordinal positions (0, 1, ... n) on the relevant axis,
#         even when the data has a numeric or date type.
#
# ...

# %%
sns.countplot(x='Sex', data=titanic_df, hue='Survived')
plt.show()

# %%
sns.countplot(x='Sex', data=titanic_df, hue=['Survived', 'PClass'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1759, in categorical_order(vector, order)
#    1758 try:
# -> 1759     order = vector.cat.categories
#    1760 except (TypeError, AttributeError):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1763, in categorical_order(vector, order)
#    1762 try:
# -> 1763     order = vector.unique()
#    1764 except AttributeError:
#
# ...

# %%
sns.countplot(x='Sex', y='PClass', data=titanic_df, hue='Survived')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 sns.countplot(x='Sex', y='PClass', data=titanic_df, hue='Survived')
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2941, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2939     y = x
#    2940 elif x is not None and y is not None:
# -> 2941     raise ValueError("Cannot pass values for both `x` and `y`")
#    2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#
# ValueError: Cannot pass values for both `x` and `y`

# %%
# scatterplot

# %%
pokemon_df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
sns.scatterplot(x='Attack', y='Defense', data=pokemon_df)
plt.show()

# %%
sns.scatterplot(x='Total', y='Speed', data=pokemon_df)
plt.show()

# %%
sns.scatterplot(x='Attack', y='Defense', data=pokemon_df, hue='Legendary')
plt.show()

# %%
# Fetch datasets from seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
iris_df = sns.load_dataset('iris')

# %%
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x='sepal_length', y='petal_width', data=iris_df)
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='petal_width', data=iris_df, hue='species')
plt.show()

# %%
sns.scatterplot(x='petal_length', y='petal_width', data=iris_df, hue='species')
plt.show()

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris_df, hue='species')
plt.show()

# %%
# Load the tips dataset from seaborn

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
tips_df['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
tips_df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips_df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips_df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tips_df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Bar plot
# x-axis => categorical col
# y-axis => numerical col
# it calculates the mean value (by default) of the numerical data for each category of the categorical col

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips_df.query("sex == 'Male'")
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
tips_df.query("sex == 'Male'")['tip'].mean()
# Out:
# 3.0896178343949043

# %%
tips_df.query("sex == 'Female'")['tip'].mean()
# Out:
# 2.8334482758620685

# %%
sns.barplot(x='sex', y='tip', data=tips_df)
plt.show()

# %%
help(sns.barplot)
# Out:
# Help on function barplot in module seaborn.categorical:
#
# barplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, errcolor='.26', errwidth=None, capsize=None, dodge=True, ci='deprecated', ax=None, **kwargs)
#     Show point estimates and errors as rectangular bars.
#
#     A bar plot represents an estimate of central tendency for a numeric
#     variable with the height of each rectangle and provides some indication of
#     the uncertainty around that estimate using error bars. Bar plots include 0
#     in the quantitative axis range, and they are a good choice when 0 is a
#     meaningful value for the quantitative variable, and you want to make
#     comparisons against it.
#
#     For datasets where 0 is not a meaningful value, a point plot will allow you
# ...

# %%
sns.barplot(x='sex', y='tip', data=tips_df, estimator='sum')
plt.show()

# %%
sns.barplot(x='sex', y='tip', data=tips_df, estimator='median')
plt.show()

# %%
sns.barplot(x='sex', y='tip', data=tips_df)
plt.show()

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='time', y='tip', data=tips_df)
plt.show()

# %%
sns.barplot(x='day', y='tip', data=tips_df)
plt.show()

# %%
sns.barplot(x='day', y='tip', data=tips_df, hue='time')
plt.show()

# %%
tips_df.query("day == 'Sat' or day == 'Sun'")
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %%
tips_df.query("(day == 'Sat' or day == 'Sun') and (time == 'Lunch')")
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
tips_df.query("(day == 'Thur') and (time == 'Dinner')")
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 243       18.78  3.0  Female     No  Thur  Dinner     2

# %%
# Regression plot

# %%
# lmplot
# finds and plots the relationship between 2 numerical cols

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_df)
plt.show()

# %%
help(sns.lmplot)
# Out:
# Help on function lmplot in module seaborn.regression:
#
# lmplot(data=None, *, x=None, y=None, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=None, sharey=None, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, facet_kws=None)
#     Plot data and regression model fits across a FacetGrid.
#
#     This function combines :func:`regplot` and :class:`FacetGrid`. It is
#     intended as a convenient interface to fit regression models across
#     conditional subsets of a dataset.
#
#     When thinking about how to assign variables to different facets, a general
# ...

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips_df)
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_df, order=2)
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips_df, order=3)
plt.show()

# %%
# Boxplot 
# used to plot the statistical summary of the data

# %%
tips_df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.boxplot(x='time', y='tip', data=tips_df)
plt.show()

# %%
sns.boxplot(y='tip', data=tips_df)
plt.show()

# %%
tips_df['tip'].describeribe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: tip, dtype: float64

# %%
# Outliers
# Values which are beyond the normal range
# Values which are far away from the mean value

# %% [markdown]
# Boxplot uses the below formula to find outliers
#
# 1. Find Q1
# 2. Find Q2
# 3. Find Interquartile range (IQR) = Q3 - Q1
# 4. Find upper and lower limits/bounds
#     - lower bound = Q1 - IQR * 1.5
#     - upper bound = Q3 + IQR * 1.5

# %%
q1 = tips_df['tip'].quantile(.25)

# %%
q1
# Out:
# 2.0

# %%
q3 = tips_df['tip'].quantile(.75)

# %%
q3
# Out:
# 3.5625

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 1.5625

# %%
lower_bound = q1 - iqr * 1.5

# %%
lower_bound
# Out:
# -0.34375

# %%
upper_bound = q3 + 1.5 * iqr

# %%
upper_bound
# Out:
# 5.90625

# %%
# Any value which is more than upper_bound and less than lower_bound will be treated as outlier by boxplot

# %%
help(sns.boxplot)
# Out:
# Help on function boxplot in module seaborn.categorical:
#
# boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)
#     Draw a box plot to show distributions with respect to categories.
#
#     A box plot (or box-and-whisker plot) shows the distribution of quantitative
#     data in a way that facilitates comparisons between variables or across
#     levels of a categorical variable. The box shows the quartiles of the
#     dataset while the whiskers extend to show the rest of the distribution,
#     except for points that are determined to be "outliers" using a method
#     that is a function of the inter-quartile range.
#
#     .. note::
#         This function always treats one of the variables as categorical and
#         draws data at ordinal positions (0, 1, ... n) on the relevant axis,
# ...

# %%
sns.boxplot(y='tip', data=tips_df)
plt.show()

# %%
sns.boxplot(y='tip', data=tips_df, whis = 2)
plt.show()
